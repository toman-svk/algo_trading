# %%
import yfinance as yf



class Finance():

    __init__(self)

# %%
import yfinance as yf
import datetime
import matplotlib.pyplot as plt

# Define the ticker symbol
tickerSymbol = 'TSLA'

# Get the data for the last 7 days
# start_date = (datetime.datetime.now() - datetime.timedelta(days=7)).strftime('%Y-%m-%d')
# end_date = datetime.datetime.now().strftime('%Y-%m-%d')

# end_date = '2023-03-12'
# start_date = '2023-03-05'


# Get the data from Yahoo Finance
tickerData = yf.Ticker(tickerSymbol)
# tickerDf = tickerData.history(start=start_date, end=end_date)
tickerDf = tickerData.history()



# Create a line chart
plt.plot(tickerDf.index, tickerDf['Close'])

# Add title and axis labels
plt.title('TSLA Close Values for the Last 7 Days')
plt.xlabel('Date')
plt.ylabel('Close Value')
plt.xticks(rotation=25)

# Display the chart
plt.show()

# %%
tickerSymbol = 'TSLA'
tickerData = yf.Ticker(tickerSymbol)

# %%
tickerData
# Out:
# yfinance.Ticker object <TSLA>

# %%
import requests

# %%
url = 'https://www.alphavantage.co/query'
params = {
    'function': 'TIME_SERIES_DAILY_ADJUSTED',
    'symbol': 'TSLA',
    'outputsize': 'compact',
    'apikey': 'IUP8ECIFSABF0MWV',
    'start_date': '2022-02-25',
    'end_date': '2022-03-04'
}

response = requests.get(url, params=params)
data = response.json()

# %%
data['Time Series (Daily)']['2023-03-10']
# Out:
# {'1. open': '175.13',
#  '2. high': '178.29',
#  '3. low': '168.44',
#  '4. close': '173.44',
#  '5. adjusted close': '173.44',
#  '6. volume': '191488872',
#  '7. dividend amount': '0.0000',
#  '8. split coefficient': '1.0'}

# %%
import yfinance as yf

# Get the TSLA stock information
tsla = yf.Ticker("TSLA")

# Get the live stock price
live_price = tsla.info['regularMarketPrice']

print("TSLA live price:", live_price)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[23], line 7
#       4 tsla = yf.Ticker("TSLA")
#       6 # Get the live stock price
# ----> 7 live_price = tsla.info['regularMarketPrice']
#       9 print("TSLA live price:", live_price)
#
# File ~/opt/anaconda3/envs/algo_trading/lib/python3.11/site-packages/yfinance/ticker.py:138, in Ticker.info(self)
#     136 @property
#     137 def info(self) -> dict:
# --> 138     return self.get_info()
#
# File ~/opt/anaconda3/envs/algo_trading/lib/python3.11/site-packages/yfinance/base.py:1475, in TickerBase.get_info(self, proxy)
#    1473 def get_info(self, proxy=None) -> dict:
#    1474     self._quote.proxy = proxy
# -> 1475     data = self._quote.info
#    1476     return data
#
# File ~/opt/anaconda3/envs/algo_trading/lib/python3.11/site-packages/yfinance/scrapers/quote.py:95, in Quote.info(self)
#      92 @property
# ...

# %%
import yfinance as yf

# Define the ticker symbol
tickerSymbol = 'TSLA'

# Get data on this ticker
tickerData = yf.Ticker(tickerSymbol)

# Get the historical prices for this ticker
tickerDf = tickerData.history(period='1d', start='2010-01-01', end='2023-03-14', interval='1d')

# Print the data
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2010-06-29 00:00:00-04:00    1.266667    1.666667    1.169333    1.592667
# 2010-06-30 00:00:00-04:00    1.719333    2.028000    1.553333    1.588667
# 2010-07-01 00:00:00-04:00    1.666667    1.728000    1.351333    1.464000
# 2010-07-02 00:00:00-04:00    1.533333    1.540000    1.247333    1.280000
# 2010-07-06 00:00:00-04:00    1.333333    1.333333    1.055333    1.074000
# ...                               ...         ...         ...         ...
# 2023-03-07 00:00:00-05:00  191.380005  194.199997  186.100006  187.710007
# 2023-03-08 00:00:00-05:00  185.039993  186.500000  180.000000  182.000000
# 2023-03-09 00:00:00-05:00  180.250000  185.179993  172.509995  172.919998
# 2023-03-10 00:00:00-05:00  175.130005  178.289993  168.440002  173.440002
# 2023-03-13 00:00:00-04:00  167.460007  177.350006  163.910004  174.479996
#
#                               Volume  Dividends  Stock Splits
# Date
# ...

# %%
tickerDf
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2010-06-29 00:00:00-04:00    1.266667    1.666667    1.169333    1.592667
# 2010-06-30 00:00:00-04:00    1.719333    2.028000    1.553333    1.588667
# 2010-07-01 00:00:00-04:00    1.666667    1.728000    1.351333    1.464000
# 2010-07-02 00:00:00-04:00    1.533333    1.540000    1.247333    1.280000
# 2010-07-06 00:00:00-04:00    1.333333    1.333333    1.055333    1.074000
# ...                               ...         ...         ...         ...
# 2023-03-07 00:00:00-05:00  191.380005  194.199997  186.100006  187.710007
# 2023-03-08 00:00:00-05:00  185.039993  186.500000  180.000000  182.000000
# 2023-03-09 00:00:00-05:00  180.250000  185.179993  172.509995  172.919998
# 2023-03-10 00:00:00-05:00  175.130005  178.289993  168.440002  173.440002
# 2023-03-13 00:00:00-04:00  167.460007  177.350006  163.910004  174.479996
#
#                               Volume  Dividends  Stock Splits
# Date
# ...

# %%
import yfinance as yf

# Define the ticker symbol and data source
tickerSymbol = 'TSLA'
dataSource = 'av'

# Create a Ticker object for TSLA using Alpha Vantage as the data source
tickerData = yf.Ticker(tickerSymbol, data_source=dataSource)

# Get the real-time price
price = tickerData.info['regularMarketPrice']

# Print the price
print(f'The real-time price for {tickerSymbol} is {price}')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 8
#       5 dataSource = 'av'
#       7 # Create a Ticker object for TSLA using Alpha Vantage as the data source
# ----> 8 tickerData = yf.Ticker(tickerSymbol, data_source=dataSource)
#      10 # Get the real-time price
#      11 price = tickerData.info['regularMarketPrice']
#
# TypeError: Ticker.__init__() got an unexpected keyword argument 'data_source'

# %% [markdown]
# # Real-time data

# %%
import requests

url = 'https://www.alphavantage.co/query'
params = {
    'function': 'GLOBAL_QUOTE',
    'symbol': 'TSLA',
    'apikey': 'IUP8ECIFSABF0MWV'
}

response = requests.get(url, params=params)
data = response.json()

# Access the current price
current_price = data['Global Quote']['05. price']
print(f"The current price of TSLA is {current_price}")
# Out:
# The current price of TSLA is 183.2600
